# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Cargamos e visualizamos o dataset
deportistas = pd.read_csv("C:/Users/samuel.pedrosapedros/Downloads/Dataset_EDA/deportistas.csv",index_col=0)
deportistas.head(5)
# Out:
#                    Name Nationality  Current Rank Previous Year Rank  \
# S.NO
# 1            Mike Tyson         USA             1                NaN
# 2        Buster Douglas         USA             2                NaN
# 3     Sugar Ray Leonard         USA             3                NaN
# 4          Ayrton Senna      Brazil             4                NaN
# 5           Alain Prost      France             5                NaN
#
#             Sport  Year  earnings ($ million)
# S.NO
# 1          boxing  1990                  28.6
# 2          boxing  1990                  26.0
# 3          boxing  1990                  13.0
# 4     auto racing  1990                  10.0
# 5     auto racing  1990                   9.0

# %%
# Comprobamos os nulos que hai no Dataset
deportistas.isnull().sum()
# Out:
# Name                     0
# Nationality              0
# Current Rank             0
# Previous Year Rank      24
# Sport                    0
# Year                     0
# earnings ($ million)     0
# dtype: int64

# %%
# Obtemos a información relativa ao dataset
deportistas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301 entries, 1 to 301
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  301 non-null    object
#  1   Nationality           301 non-null    object
#  2   Current Rank          301 non-null    int64
#  3   Previous Year Rank    277 non-null    object
#  4   Sport                 301 non-null    object
#  5   Year                  301 non-null    int64
#  6   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 18.8+ KB

# %%
# Renomeamos ás columnas que poden dar problemas
deportistas = deportistas.rename(columns={'Current Rank':'Rank_actual','Previous Year Rank':'Rank_anterior','earnings ($ million)':'ganancias'})
deportistas.head(5)
# Out:
#                    Name Nationality  Rank_actual Rank_anterior        Sport  \
# S.NO
# 1            Mike Tyson         USA            1   Descoñecido       boxing
# 2        Buster Douglas         USA            2   Descoñecido       boxing
# 3     Sugar Ray Leonard         USA            3   Descoñecido       boxing
# 4          Ayrton Senna      Brazil            4   Descoñecido  auto racing
# 5           Alain Prost      France            5   Descoñecido  auto racing
#
#       Year  ganancias
# S.NO
# 1     1990       28.6
# 2     1990       26.0
# 3     1990       13.0
# 4     1990       10.0
# 5     1990        9.0

# %%
#Quitamos os valores nulos da columna Previous Year Rank
deportistas.Rank_anterior=deportistas.Rank_anterior.fillna('Descoñecido')
deportistas.head()
# Out:
#                    Name Nationality  Rank_actual Rank_anterior        Sport  \
# S.NO
# 1            Mike Tyson         USA            1   Descoñecido       boxing
# 2        Buster Douglas         USA            2   Descoñecido       boxing
# 3     Sugar Ray Leonard         USA            3   Descoñecido       boxing
# 4          Ayrton Senna      Brazil            4   Descoñecido  auto racing
# 5           Alain Prost      France            5   Descoñecido  auto racing
#
#       Year  ganancias
# S.NO
# 1     1990       28.6
# 2     1990       26.0
# 3     1990       13.0
# 4     1990       10.0
# 5     1990        9.0

# %%
# Comprobamos a evolución dos salarios dos deportistas ao longo dos anos,
#onde podemos deducir que a medida que avanzou o tempo,
#os deportistas gañaban máis diñeiro
sns.lineplot(x='Year',y='ganancias',data=deportistas)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='ganancias'>

# %%
# Ordenamos os deportistas por ganancias para ver se se corresponden ca gráfica anterior
deportistas.sort_values('ganancias', ascending=False)
# Out:
#                    Name  Nationality  Rank_actual Rank_anterior       Sport  \
# S.NO
# 242    Floyd Mayweather          USA            1             1      Boxing
# 272    Floyd Mayweather          USA            1          >100      Boxing
# 243      Manny Pacquiao  Philippines            2            11      Boxing
# 282        Lionel Messi    Argentina            1             2      Soccer
# 172         Tiger Woods          USA            1             1        golf
# ...                 ...          ...          ...           ...         ...
# 20    Sugar Ray Leonard          USA           10             6        golf
# 30         Monica Seles          USA           10            12      Tennis
# 10    Evander Holyfield          USA            8   Descoñecido      boxing
# 9         Arnold Palmer          USA            8   Descoñecido        golf
# 8        Michael Jordan          USA            8   Descoñecido  basketball
#
#       Year  ganancias
# S.NO
# 242   2015      300.0
# 272   2018      285.0
# 243   2015      160.0
# 282   2019      127.0
# 172   2008      115.0
# ...    ...        ...
# 20    1991        8.5
# 30    1992        8.5
# 10    1990        8.1
# 9     1990        8.1
# 8     1990        8.1
#
# [301 rows x 7 columns]
